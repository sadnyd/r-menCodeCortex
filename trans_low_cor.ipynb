# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Load the cleaned dataset
df_org = pd.read_csv('cleaned.csv', parse_dates=['Time', 'DateTime'])

# %%
df = df_org[df_org['CH Load'] != 0].reset_index(drop=True)

# %%
# Extract time-based features
df['Hour'] = df['Time'].dt.hour
df['DayOfWeek'] = df['Time'].dt.dayofweek  # Monday=0, Sunday=6
df['IsWeekend'] = df['DayOfWeek'].apply(lambda x: 1 if x >= 5 else 0)

# %%
features = [
    'kW_RT', 'kW_CHP', 'kW_CHS',
    'kW_CDS', 'kW_CT', 'GPM', 'CHWS', 'CHWR',
    'CDLO', 'DeltaCT', 'Hz_ CHP', 'Hz_CHS',
    'Hz_CDS', 'Hz_CT', 'Precent_CH', 'Precent_ CHP',
    'Precent_CDS', 'Precent_CT', 'RH [%]', 'Temperature [°C]',
    'WBT_C', 'Hour', 'DayOfWeek', 'IsWeekend'
]

# %%
# Define the target variable
target = 'CH Load'

# %%
# Select features and target
X = df[features]
y = df[target]

# %%
# Split data into training and testing sets (chronologically)
n_samples = len(df)
train_size = int(0.8 * n_samples)

X_train = X.iloc[:train_size]
y_train = y.iloc[:train_size]

X_test = X.iloc[train_size:]
y_test = y.iloc[train_size:]

# %%
# Initialize the scaler
scaler = MinMaxScaler()
# Fit the scaler on the training data
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
# Transform both training and testing data
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Define the sequence length
seq_length = 24  # Number of time steps (e.g., hourly data over a day)

# Function to create sequences
def create_sequences(X, y, seq_length):
    Xs = []
    ys = []
    for i in range(len(X) - seq_length):
        Xs.append(X[i:i+seq_length])
        ys.append(y[i+seq_length])
    return np.array(Xs), np.array(ys)

# %%
# Create sequences for training data
X_train_seq, y_train_seq = create_sequences(X_train_scaled, y_train.values, seq_length)

# Create sequences for testing data
X_test_seq, y_test_seq = create_sequences(X_test_scaled, y_test.values, seq_length)

# %%
# Define the Positional Encoding class
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, position, d_model):
        super(PositionalEncoding, self).__init__()
        self.pos_encoding = self.positional_encoding(position, d_model)

    def get_config(self):
        config = super().get_config().copy()
        return config

    def positional_encoding(self, position, d_model):
        angle_rads = self.get_angles(
            np.arange(position)[:, np.newaxis],
            np.arange(d_model)[np.newaxis, :],
            d_model)
        # Apply sin to even indices and cos to odd indices
        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        return tf.cast(angle_rads[np.newaxis, ...], dtype=tf.float32)

    def get_angles(self, pos, i, d_model):
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        return pos * angle_rates

    def call(self, x):
        return x + self.pos_encoding[:, :tf.shape(x)[1], :]

# %%
# Define the Transformer Encoder layer
def transformer_encoder_layer(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Multi-Head Attention
    x = tf.keras.layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout)(inputs, inputs)
    x = tf.keras.layers.Dropout(dropout)(x)
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Network
    x = tf.keras.layers.Conv1D(filters=ff_dim, kernel_size=1, activation='relu')(res)
    x = tf.keras.layers.Dropout(dropout)(x)
    x = tf.keras.layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

# %%
# Build the Transformer model
def build_model(seq_length, num_features, head_size, num_heads, ff_dim, num_transformer_blocks, mlp_units, dropout=0):
    inputs = tf.keras.Input(shape=(seq_length, num_features))
    x = inputs
    # Add Positional Encoding
    x = PositionalEncoding(seq_length, num_features)(x)

    # Transformer blocks
    for _ in range(num_transformer_blocks):
        x = transformer_encoder_layer(x, head_size, num_heads, ff_dim, dropout)

    x = tf.keras.layers.GlobalAveragePooling1D()(x)
    for units in mlp_units:
        x = tf.keras.layers.Dense(units, activation='relu')(x)
        x = tf.keras.layers.Dropout(dropout)(x)
    outputs = tf.keras.layers.Dense(1)(x)
    model = tf.keras.Model(inputs, outputs)
    return model

# %%
# Instantiate the model
model = build_model(
    seq_length=seq_length,
    num_features=X_train_seq.shape[2],
    head_size=64,
    num_heads=4,
    ff_dim=128,
    num_transformer_blocks=4,
    mlp_units=[64],
    dropout=0.1
)

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
              loss='mean_squared_error',
              metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Display model architecture
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 24, 24)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ positional_encoding │ (None, 24, 24)    │          0 │ input_layer[0][0] │
# │ (PositionalEncodin… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 24, 24)    │     25,368 │ positional_encod… │
# │ (MultiHeadAttentio… │                   │            │ positional_encod… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 24, 24)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 24, 24)    │         48 │ dropout_1[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 24, 24)    │          0 │ layer_normalizat… │
# │                     │                   │            │ positional_encod… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 24, 128)   │      3,200 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 24, 128)   │          0 │ conv1d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 24, 24)    │      3,096 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 24, 24)    │         48 │ conv1d_1[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 24, 24)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 24, 24)    │     25,368 │ add_1[0][0],      │
# │ (MultiHeadAttentio… │                   │            │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 24, 24)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 24, 24)    │         48 │ dropout_4[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 24, 24)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 24, 128)   │      3,200 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 24, 128)   │          0 │ conv1d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 24, 24)    │      3,096 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 24, 24)    │         48 │ conv1d_3[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 24, 24)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 24, 24)    │     25,368 │ add_3[0][0],      │
# │ (MultiHeadAttentio… │                   │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 24, 24)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 24, 24)    │         48 │ dropout_7[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 24, 24)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 24, 128)   │      3,200 │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 24, 128)   │          0 │ conv1d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 24, 24)    │      3,096 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 24, 24)    │         48 │ conv1d_5[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 24, 24)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 24, 24)    │     25,368 │ add_5[0][0],      │
# │ (MultiHeadAttentio… │                   │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 24, 24)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 24, 24)    │         48 │ dropout_10[0][0]  │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 24, 24)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 24, 128)   │      3,200 │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 24, 128)   │          0 │ conv1d_6[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 24, 24)    │      3,096 │ dropout_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 24, 24)    │         48 │ conv1d_7[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 24, 24)    │          0 │ layer_normalizat… │
# │                     │                   │            │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 24)        │          0 │ add_7[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │      1,600 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 64)        │          0 │ dense[0][0]       │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │         65 │ dropout_12[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 128,705 (502.75 KB)
#  Trainable params: 128,705 (502.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(
    X_train_seq, y_train_seq,
    validation_split=0.1,
    epochs=50,
    batch_size=16
)
# Out:
# Epoch 1/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 52.7136 - root_mean_squared_error: 7.2576 - val_loss: 70.8301 - val_root_mean_squared_error: 8.4161
# Epoch 2/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 47.1595 - root_mean_squared_error: 6.8663 - val_loss: 86.6048 - val_root_mean_squared_error: 9.3062
# Epoch 3/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 45.6241 - root_mean_squared_error: 6.7508 - val_loss: 89.1718 - val_root_mean_squared_error: 9.4431
# Epoch 4/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 49.5150 - root_mean_squared_error: 7.0350 - val_loss: 71.8716 - val_root_mean_squared_error: 8.4777
# Epoch 5/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 46.7321 - root_mean_squared_error: 6.8317 - val_loss: 61.4057 - val_root_mean_squared_error: 7.8362
# Epoch 6/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 51.3659 - root_mean_squared_error: 7.1657 - val_loss: 73.9209 - val_root_mean_squared_error: 8.5977
# Epoch 7/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 46.2378 - root_mean_squared_error: 6.7972 - val_loss: 90.9770 - val_root_mean_squared_error: 9.5382
# Epoch 8/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 46.6179 - root_mean_squared_error: 6.8265 - val_loss: 93.3929 - val_root_mean_squared_error: 9.6640
# Epoch 9/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 49.1395 - root_mean_squared_error: 7.0091 - val_loss: 107.3105 - val_root_mean_squared_error: 10.3591
# Epoch 10/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 48.0836 - root_mean_squared_error: 6.9317 - val_loss: 105.7878 - val_root_mean_squared_error: 10.2853
# Epoch 11/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 46.5177 - root_mean_squared_error: 6.8185 - val_loss: 88.7489 - val_root_mean_squared_error: 9.4207
# Epoch 12/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 45.5789 - root_mean_squared_error: 6.7497 - val_loss: 75.1674 - val_root_mean_squared_error: 8.6699
# Epoch 13/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 45.1927 - root_mean_squared_error: 6.7212 - val_loss: 107.7279 - val_root_mean_squared_error: 10.3792
# Epoch 14/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 47.9633 - root_mean_squared_error: 6.9240 - val_loss: 104.3560 - val_root_mean_squared_error: 10.2155
# Epoch 15/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 48.5664 - root_mean_squared_error: 6.9662 - val_loss: 99.2825 - val_root_mean_squared_error: 9.9641
# Epoch 16/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 44.1833 - root_mean_squared_error: 6.6443 - val_loss: 97.5261 - val_root_mean_squared_error: 9.8755
# Epoch 17/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 43.3229 - root_mean_squared_error: 6.5798 - val_loss: 80.9571 - val_root_mean_squared_error: 8.9976
# Epoch 18/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 46.2349 - root_mean_squared_error: 6.7938 - val_loss: 90.1750 - val_root_mean_squared_error: 9.4961
# Epoch 19/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 40.1678 - root_mean_squared_error: 6.3328 - val_loss: 119.2861 - val_root_mean_squared_error: 10.9218
# Epoch 20/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 43.3628 - root_mean_squared_error: 6.5824 - val_loss: 92.9869 - val_root_mean_squared_error: 9.6430
# Epoch 21/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 45.7666 - root_mean_squared_error: 6.7646 - val_loss: 91.9550 - val_root_mean_squared_error: 9.5893
# Epoch 22/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 44.2155 - root_mean_squared_error: 6.6476 - val_loss: 95.7546 - val_root_mean_squared_error: 9.7854
# Epoch 23/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 41.3812 - root_mean_squared_error: 6.4290 - val_loss: 98.0606 - val_root_mean_squared_error: 9.9026
# Epoch 24/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 44.1816 - root_mean_squared_error: 6.6448 - val_loss: 104.2291 - val_root_mean_squared_error: 10.2093
# Epoch 25/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 42.8002 - root_mean_squared_error: 6.5410 - val_loss: 90.7027 - val_root_mean_squared_error: 9.5238
# Epoch 26/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 44.9995 - root_mean_squared_error: 6.7071 - val_loss: 123.7231 - val_root_mean_squared_error: 11.1231
# Epoch 27/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 43.5014 - root_mean_squared_error: 6.5884 - val_loss: 125.5541 - val_root_mean_squared_error: 11.2051
# Epoch 28/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 44.1639 - root_mean_squared_error: 6.6427 - val_loss: 99.0702 - val_root_mean_squared_error: 9.9534
# Epoch 29/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 41.4579 - root_mean_squared_error: 6.4357 - val_loss: 131.6639 - val_root_mean_squared_error: 11.4745
# Epoch 30/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 40.3368 - root_mean_squared_error: 6.3497 - val_loss: 94.4512 - val_root_mean_squared_error: 9.7186
# Epoch 31/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 40.9970 - root_mean_squared_error: 6.3998 - val_loss: 141.0014 - val_root_mean_squared_error: 11.8744
# Epoch 32/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 48.2664 - root_mean_squared_error: 6.9395 - val_loss: 120.1881 - val_root_mean_squared_error: 10.9630
# Epoch 33/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 40.8162 - root_mean_squared_error: 6.3872 - val_loss: 110.5255 - val_root_mean_squared_error: 10.5131
# Epoch 34/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 42.7762 - root_mean_squared_error: 6.5396 - val_loss: 139.2116 - val_root_mean_squared_error: 11.7988
# Epoch 35/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 41.3089 - root_mean_squared_error: 6.4146 - val_loss: 107.4613 - val_root_mean_squared_error: 10.3664
# Epoch 36/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 43.0084 - root_mean_squared_error: 6.5571 - val_loss: 108.8714 - val_root_mean_squared_error: 10.4341
# Epoch 37/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 41.7830 - root_mean_squared_error: 6.4624 - val_loss: 128.8774 - val_root_mean_squared_error: 11.3524
# Epoch 38/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 41.7553 - root_mean_squared_error: 6.4600 - val_loss: 119.2422 - val_root_mean_squared_error: 10.9198
# Epoch 39/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 40.2188 - root_mean_squared_error: 6.3389 - val_loss: 98.8447 - val_root_mean_squared_error: 9.9421
# Epoch 40/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 42.6367 - root_mean_squared_error: 6.5279 - val_loss: 105.1100 - val_root_mean_squared_error: 10.2523
# Epoch 41/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 42.0312 - root_mean_squared_error: 6.4818 - val_loss: 114.8638 - val_root_mean_squared_error: 10.7175
# Epoch 42/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 42.4439 - root_mean_squared_error: 6.5136 - val_loss: 86.8743 - val_root_mean_squared_error: 9.3206
# Epoch 43/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 39.4558 - root_mean_squared_error: 6.2803 - val_loss: 84.0397 - val_root_mean_squared_error: 9.1673
# Epoch 44/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 39.7664 - root_mean_squared_error: 6.3043 - val_loss: 97.4680 - val_root_mean_squared_error: 9.8726
# Epoch 45/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 40.7830 - root_mean_squared_error: 6.3837 - val_loss: 128.8515 - val_root_mean_squared_error: 11.3513
# Epoch 46/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 42.2029 - root_mean_squared_error: 6.4904 - val_loss: 106.8191 - val_root_mean_squared_error: 10.3353
# Epoch 47/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 42.0776 - root_mean_squared_error: 6.4857 - val_loss: 102.2743 - val_root_mean_squared_error: 10.1131
# Epoch 48/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 42.2150 - root_mean_squared_error: 6.4914 - val_loss: 94.8691 - val_root_mean_squared_error: 9.7401
# Epoch 49/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 42.7189 - root_mean_squared_error: 6.5348 - val_loss: 74.7263 - val_root_mean_squared_error: 8.6444
# Epoch 50/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 39.2433 - root_mean_squared_error: 6.2632 - val_loss: 102.9384 - val_root_mean_squared_error: 10.1459

# %%
# Predict on the test set
y_pred = model.predict(X_test_seq)
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step

# %%
# Evaluate the model
mae = mean_absolute_error(y_test_seq, y_pred)
rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))
r2 = r2_score(y_test_seq, y_pred)

print(f"Test MAE: {mae:.2f}")
print(f"Test RMSE: {rmse:.2f}")
print(f"Test R^2 Score: {r2:.2f}")
# Out:
# Test MAE: 5.71
# Test RMSE: 7.46
# Test R^2 Score: 0.69

# %%
import matplotlib.pyplot as plt

# 1. Plot Training & Validation Loss Over Epochs
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Model Loss Over Epochs', fontsize=16)
plt.ylabel('Loss (MSE)', fontsize=14)
plt.xlabel('Epoch', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.show()

# 2. Plot Actual vs. Predicted CH Load on the Test Set
plt.figure(figsize=(12, 6))
plt.plot(y_test_seq, label='Actual CH Load', color='blue')
plt.plot(y_pred, label='Predicted CH Load', color='red', alpha=0.7)
plt.title('Actual vs. Predicted CH Load', fontsize=16)
plt.ylabel('CH Load (%)', fontsize=14)
plt.xlabel('Time Steps', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.show()


# 3. Predicted vs. Actual Scatter Plot
plt.figure(figsize=(8, 8))
plt.scatter(y_test_seq, y_pred, alpha=0.5, color='green')
plt.title('Predicted vs. Actual CH Load', fontsize=16)
plt.xlabel('Actual CH Load (%)', fontsize=14)
plt.ylabel('Predicted CH Load (%)', fontsize=14)
plt.grid(True)
# Plot a diagonal line for reference
max_val = max(y_test_seq.max(), y_pred.max())
min_val = min(y_test_seq.min(), y_pred.min())
plt.plot([min_val, max_val], [min_val, max_val], 'r--')
plt.show()

# %%
# Save the model after training
model.save('transformer_chiller_model_low.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Load the new dataset
new_df = pd.read_csv('cleaned1.csv', parse_dates=['Time', 'DateTime'])

# %%
# If 'CH Load' is present and you want to drop rows where it's zero
if 'CH Load' in new_df.columns:
    new_df = new_df[new_df['CH Load'] != 0].reset_index(drop=True)

# %%
# Extract time-based features
new_df['Hour'] = new_df['Time'].dt.hour
new_df['DayOfWeek'] = new_df['Time'].dt.dayofweek  # Monday=0, Sunday=6
new_df['IsWeekend'] = new_df['DayOfWeek'].apply(lambda x: 1 if x >= 5 else 0)

# %%
# Select features
X_new = new_df[features]

# Scale the features using the loaded scaler
X_new_scaled = scaler.transform(X_new)

# %%
# Define the sequence length (same as used during training)
seq_length = 24  # or the value you used

# Function to create sequences
def create_sequences(X, seq_length):
    Xs = []
    for i in range(len(X) - seq_length):
        Xs.append(X[i:i+seq_length])
    return np.array(Xs)

# Create sequences for the new data
X_new_seq = create_sequences(X_new_scaled, seq_length)

# %%
# Make predictions on the new data
y_new_pred = model.predict(X_new_seq)
# Out:
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step

# %%
# The actual 'CH Load' values after sequence creation (shift by `seq_length`)
actual_ch_load = new_df['CH Load'].values[seq_length:]

# %%
# Create a DataFrame to store actual and predicted values along with timestamps
comparison_df = pd.DataFrame({
    'Time': new_df['Time'][seq_length:].reset_index(drop=True),
    'Actual CH Load': actual_ch_load,
    'Predicted CH Load': y_new_pred.squeeze()
})

# %%
# Plot Actual vs Predicted CH Load
plt.figure(figsize=(12, 6))
plt.plot(comparison_df['Time'], comparison_df['Actual CH Load'], label='Actual CH Load', color='blue')
plt.plot(comparison_df['Time'], comparison_df['Predicted CH Load'], label='Predicted CH Load', color='red', alpha=0.7)
plt.title('Actual vs Predicted CH Load', fontsize=16)
plt.xlabel('Time', fontsize=14)
plt.ylabel('CH Load (%)', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True)
plt.show()

# %%
# If 'CH Load' is available in new data
if 'CH Load' in new_df.columns:
    y_new_actual = new_df['CH Load'].values[seq_length:]
    # Calculate evaluation metrics
    mae = mean_absolute_error(y_new_actual, y_new_pred)
    rmse = np.sqrt(mean_squared_error(y_new_actual, y_new_pred))
    r2 = r2_score(y_new_actual, y_new_pred)
    print(f"New Data MAE: {mae:.2f}")
    print(f"New Data RMSE: {rmse:.2f}")
    print(f"New Data R^2 Score: {r2:.2f}")
# Out:
# New Data MAE: 5.29
# New Data RMSE: 6.36
# New Data R^2 Score: 0.88
